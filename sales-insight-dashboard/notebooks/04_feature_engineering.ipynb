# %%
import sys
sys.path.append("..")

from src.feature_engineering import feature_engineering_pipeline

df_features = feature_engineering_pipeline(
    input_path="../data/processed/daily_sales.csv",
    output_path="../data/processed/daily_sales_features.csv"
)

df_features.head(10)
# Out:
# Loaded daily sales: 1458 rows, 3 columns
# Added calendar features: year, month, day, day_of_week, day_of_year, week_of_year, quarter, is_weekend, is_month_start, is_month_end, is_holiday_season
# Added lag features for lags: [1, 7, 14, 30]
# Added rolling mean/std features for windows: [7, 30]
# Dropped 30 rows with NaN (from lag/rolling window warm-up period)
#
# Feature-engineered data saved to: ..\data\processed\daily_sales_features.csv
# Final shape: 1428 rows, 22 columns
#
# Final columns: ['order_date', 'total_sales', 'total_orders', 'year', 'month', 'day', 'day_of_week', 'day_of_year', 'week_of_year', 'quarter', 'is_weekend', 'is_month_start', 'is_month_end', 'is_holiday_season', 'total_sales_lag_1', 'total_sales_lag_7', 'total_sales_lag_14', 'total_sales_lag_30', 'total_sales_roll_mean_7', 'total_sales_roll_std_7', 'total_sales_roll_mean_30', 'total_sales_roll_std_30']
#   order_date  total_sales  total_orders  year  month  day  day_of_week  \
# ...

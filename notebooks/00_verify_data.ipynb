# %%
import pandas as pd

df = pd.read_csv("sales-insight-dashboard/data/raw/superstore_sales.csv", encoding="latin-1")
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nData types:\n", df.dtypes)

df.head()
# Out:
# Shape: (9994, 13)
#
# Columns: ['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit']
#
# Data types:
#  Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...

# %%
import os

print(os.getcwd())
# Out:
# C:\Internship\Projects\Business Insight Dashboard with ML Forecasting

# %%
import os

print(os.path.exists("../data/raw/superstore_sales.csv"))
# Out:
# False

# %%
import os

print(os.getcwd())
print(os.path.exists("../data/raw/superstore_sales.csv"))
# Out:
# C:\Internship\Projects\Business Insight Dashboard with ML Forecasting
# False

# %%
import os

print(os.path.exists("data/raw/superstore_sales.csv"))
# Out:
# False

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# .\sales-insight-dashboard\data\raw\superstore_sales.csv
# .\sales-insight-dashboard\venv\Lib\site-packages\matplotlib\mpl-data\sample_data\data_x_x2_x3.csv
# .\sales-insight-dashboard\venv\Lib\site-packages\matplotlib\mpl-data\sample_data\msft.csv
# .\sales-insight-dashboard\venv\Lib\site-packages\matplotlib\mpl-data\sample_data\Stocks.csv
# .\sales-insight-dashboard\venv\Lib\site-packages\numpy\random\tests\data\mt19937-testset-1.csv
# .\sales-insight-dashboard\venv\Lib\site-packages\numpy\random\tests\data\mt19937-testset-2.csv
# .\sales-insight-dashboard\venv\Lib\site-packages\numpy\random\tests\data\pcg64-testset-1.csv
# .\sales-insight-dashboard\venv\Lib\site-packages\numpy\random\tests\data\pcg64-testset-2.csv
# .\sales-insight-dashboard\venv\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-1.csv
# .\sales-insight-dashboard\venv\Lib\site-packages\numpy\random\tests\data\pcg64dxsm-testset-2.csv
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Internship\Projects\Business Insight Dashboard with ML Forecasting
